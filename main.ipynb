# %% [markdown]
# # Read data

# %%
import csv
import os

# open and read .csv
f = open(f"{os.getcwd()}\\data\\106_MLII.csv", "r")
data = csv.reader(f)

next(data) # skip header

# Convert type csv_reader to list
# csv_reader --> list
y: list = []
for row in data:
    y.append(int(row[0]))
# close .csv
f.close()

print(y[:10])
# Out:
# [962, 962, 962, 962, 962, 962, 962, 962, 966, 967]

# %% [markdown]
# # Show Graph

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array(y)
plt.figure(figsize=(100, 20))
plt.plot(y[:1000])
plt.show()

# %% [markdown]
# # Find Peak

# %%
from scipy.signal import find_peaks

# y over 1250
peaks, _ = find_peaks(y, height=(1100, 1600), distance=200)
plt.figure(figsize=(500, 20), frameon=False)
plt.plot(y[:])
plt.plot(peaks[:], y[:][peaks[:]], "x")
# plt.savefig(f"{os.getcwd()}\\train_data\\1")
print(len(peaks))
plt.show()
# Out:
# 1749
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Administrator\Projects\Embedded_Contest\venv\lib\site-packages\PIL\ImageFile.py:515, in _save(im, fp, tile, bufsize)
#     514 try:
# --> 515     fh = fp.fileno()
#     516     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       8 # plt.savefig(f"{os.getcwd()}\\train_data\\1")
#       9 print(len(peaks))
# ---> 10 plt.show()
#
# File c:\Users\Administrator\Projects\Embedded_Contest\venv\lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# ...

# %% [markdown]
# # Split Figure

# %%
print(len(peaks))
for pulse_N in range(1, len(peaks)-1):
    fig = plt.figure(frameon=False)
    fig.set_size_inches(2, 2)
    ax = fig.add_axes([0, 0, 1, 1])
    ax.axis("off")
    ax.plot(y[peaks[pulse_N]: peaks[pulse_N+1]])
    try:
        fig.savefig(f"{os.getcwd()}\\train_data\\{pulse_N}", format="png")
    except:
        os.makedirs("train_data")
        fig.savefig(f"{os.getcwd()}\\train_data\\{pulse_N}", format="png")
    plt.close()
# Out:
# 1749
